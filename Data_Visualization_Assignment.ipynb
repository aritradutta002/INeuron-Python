# %% [markdown]
# ## In this assignment students have to transform iris data into 3 dimensions and plot a 3d chart with transformed dimensions and colour each data point with specific class.

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = plt.axes(projection='3d')
d = {'setosa':1,'virginica':2,'versicolor':3}
df['species1'] = df['species'].map(d)
# Data for a three-dimensional line
zline = df['sepal_length']
xline = df['sepal_width']
yline = df['petal_length']
ax.scatter3D(xline, yline, zline, c = df['species1'])
plt.show()

# %%
ax = plt.axes(projection='3d')
zline = df['sepal_length']
xline = df['sepal_width']
yline = df['petal_width']
ax.scatter3D(xline, yline, zline, c = df['species1'])
plt.show()

# %%
ax = plt.axes(projection='3d')
zline = df['sepal_length']
xline = df['petal_length']
yline = df['petal_width']
ax.scatter3D(xline, yline, zline, c = df['species1'])
plt.show()

# %%
ax = plt.axes(projection='3d')
zline = df['sepal_width']
xline = df['petal_length']
yline = df['petal_width']
ax.scatter3D(xline, yline, zline, c = df['species1'])
plt.show()
